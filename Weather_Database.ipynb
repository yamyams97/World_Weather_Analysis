# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | sakata
# Processing Record 4 of Set 1 | murgab
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | brigantine
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | khani
# Processing Record 14 of Set 1 | vinh yen
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | nelson bay
# Processing Record 17 of Set 1 | lavrentiya
# Processing Record 18 of Set 1 | kurumkan
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | west bay
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | katsuura
# Processing Record 25 of Set 1 | mount darwin
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | namatanai
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | saltillo
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | jamsa
# Processing Record 34 of Set 1 | kokopo
# Processing Record 35 of Set 1 | grakhovo
# Processing Record 36 of Set 1 | marrakesh
# Processing Record 37 of Set 1 | vestmannaeyjar
# Processing Record 38 of Set 1 | mehamn
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | ngunguru
# Processing Record 41 of Set 1 | goderich
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | paramirim
# Processing Record 47 of Set 1 | san patricio
# Processing Record 48 of Set 1 | kahului
# Processing Record 49 of Set 1 | aguimes
# Processing Record 50 of Set 1 | san jose
# Processing Record 1 of Set 2 | santa cruz
# Processing Record 2 of Set 2 | santa rita arriba
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | tungor
# Processing Record 6 of Set 2 | laibin
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | cabedelo
# Processing Record 9 of Set 2 | fairbanks
# Processing Record 10 of Set 2 | kurilsk
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | san angelo
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | husavik
# Processing Record 16 of Set 2 | chumikan
# Processing Record 17 of Set 2 | udachnyy
# Processing Record 18 of Set 2 | santa rosa
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | yeppoon
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | lahad datu
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | ulladulla
# Processing Record 26 of Set 2 | espanola
# Processing Record 27 of Set 2 | fomboni
# Processing Record 28 of Set 2 | cayenne
# Processing Record 29 of Set 2 | cockburn town
# Processing Record 30 of Set 2 | corrente
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | keuruu
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | esperance
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | codajas
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | kommunisticheskiy
# Processing Record 42 of Set 2 | kabo
# Processing Record 43 of Set 2 | letca
# Processing Record 44 of Set 2 | inhambane
# Processing Record 45 of Set 2 | ahipara
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | rio grande
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | binabalian
# Processing Record 50 of Set 2 | xifeng
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | chirkey
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | sobolevo
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | sierpc
# Processing Record 8 of Set 3 | hope
# Processing Record 9 of Set 3 | sungairaya
# Processing Record 10 of Set 3 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | lashio
# Processing Record 15 of Set 3 | nishihara
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | peruibe
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | argentan
# Processing Record 21 of Set 3 | ust-ishim
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | tabou
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | jardim de piranhas
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | nemuro
# Processing Record 30 of Set 3 | conceicao do araguaia
# Processing Record 31 of Set 3 | samarai
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | puerto madryn
# Processing Record 36 of Set 3 | mount gambier
# Processing Record 37 of Set 3 | tiksi
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | rawah
# Processing Record 41 of Set 3 | harper
# Processing Record 42 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | marawi
# Processing Record 46 of Set 3 | atar
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | cape town
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | vanavara
# Processing Record 3 of Set 4 | caohe
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | tual
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | manggar
# Processing Record 9 of Set 4 | nunguan
# Processing Record 10 of Set 4 | iberia
# Processing Record 11 of Set 4 | odweyne
# Processing Record 12 of Set 4 | ardakan
# Processing Record 13 of Set 4 | lodja
# Processing Record 14 of Set 4 | swan river
# Processing Record 15 of Set 4 | am timan
# Processing Record 16 of Set 4 | beaupre
# Processing Record 17 of Set 4 | kirando
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | palghar
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | xiongyue
# Processing Record 25 of Set 4 | roma
# Processing Record 26 of Set 4 | pueblo
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | laharpur
# Processing Record 29 of Set 4 | sisimiut
# Processing Record 30 of Set 4 | vao
# Processing Record 31 of Set 4 | sinnamary
# Processing Record 32 of Set 4 | cururupu
# Processing Record 33 of Set 4 | saint-georges
# Processing Record 34 of Set 4 | sterling
# Processing Record 35 of Set 4 | likasi
# Processing Record 36 of Set 4 | terney
# Processing Record 37 of Set 4 | canete
# Processing Record 38 of Set 4 | sandakan
# Processing Record 39 of Set 4 | baglung
# Processing Record 40 of Set 4 | tiarei
# Processing Record 41 of Set 4 | szeghalom
# Processing Record 42 of Set 4 | vaini
# Processing Record 43 of Set 4 | natchez
# Processing Record 44 of Set 4 | kirakira
# Processing Record 45 of Set 4 | wenzhou
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | meulaboh
# Processing Record 50 of Set 4 | nushki
# Processing Record 1 of Set 5 | aberdeen
# Processing Record 2 of Set 5 | oktyabrskoye
# Processing Record 3 of Set 5 | natal
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | cah ab
# City not found. Skipping...
# Processing Record 6 of Set 5 | dunedin
# Processing Record 7 of Set 5 | giyani
# Processing Record 8 of Set 5 | half moon bay
# Processing Record 9 of Set 5 | klokkarvik
# City not found. Skipping...
# Processing Record 10 of Set 5 | coihaique
# Processing Record 11 of Set 5 | basco
# Processing Record 12 of Set 5 | jackson
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | trofors
# Processing Record 15 of Set 5 | bilibino
# Processing Record 16 of Set 5 | marsa matruh
# Processing Record 17 of Set 5 | mackay
# Processing Record 18 of Set 5 | leh
# Processing Record 19 of Set 5 | colares
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | dwarka
# Processing Record 22 of Set 5 | kamenka
# Processing Record 23 of Set 5 | cam ranh
# Processing Record 24 of Set 5 | great yarmouth
# Processing Record 25 of Set 5 | nouadhibou
# Processing Record 26 of Set 5 | avarua
# Processing Record 27 of Set 5 | dikson
# Processing Record 28 of Set 5 | sainte-suzanne
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 5 | lima
# Processing Record 32 of Set 5 | garwa
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | arlit
# Processing Record 35 of Set 5 | hervey bay
# Processing Record 36 of Set 5 | arica
# Processing Record 37 of Set 5 | ust-kuyga
# Processing Record 38 of Set 5 | guerrero negro
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | komsomolskiy
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | boende
# Processing Record 43 of Set 5 | tymovskoye
# Processing Record 44 of Set 5 | wakkanai
# Processing Record 45 of Set 5 | pevek
# Processing Record 46 of Set 5 | kungurtug
# Processing Record 47 of Set 5 | boyolangu
# Processing Record 48 of Set 5 | kandrian
# Processing Record 49 of Set 5 | roald
# Processing Record 50 of Set 5 | hilton head island
# Processing Record 1 of Set 6 | castro
# Processing Record 2 of Set 6 | neiafu
# Processing Record 3 of Set 6 | impfondo
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | nampula
# Processing Record 6 of Set 6 | port keats
# Processing Record 7 of Set 6 | batemans bay
# Processing Record 8 of Set 6 | cherskiy
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | gurupi
# Processing Record 11 of Set 6 | jepara
# Processing Record 12 of Set 6 | kavieng
# Processing Record 13 of Set 6 | uk
# City not found. Skipping...
# Processing Record 14 of Set 6 | vanderhoof
# Processing Record 15 of Set 6 | suditi
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | miri
# Processing Record 19 of Set 6 | port hedland
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | loudi
# Processing Record 22 of Set 6 | hualmay
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | linhares
# Processing Record 25 of Set 6 | lubango
# Processing Record 26 of Set 6 | hobyo
# Processing Record 27 of Set 6 | lubao
# Processing Record 28 of Set 6 | yuyao
# Processing Record 29 of Set 6 | gezing
# Processing Record 30 of Set 6 | veletma
# City not found. Skipping...
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | kathmandu
# Processing Record 33 of Set 6 | baneh
# Processing Record 34 of Set 6 | nanortalik
# Processing Record 35 of Set 6 | dovolnoye
# Processing Record 36 of Set 6 | fuyang
# Processing Record 37 of Set 6 | endicott
# Processing Record 38 of Set 6 | muros
# Processing Record 39 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 6 | laguna
# Processing Record 41 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 6 | rafraf
# Processing Record 44 of Set 6 | balkanabat
# Processing Record 45 of Set 6 | tete
# Processing Record 46 of Set 6 | mnogovershinnyy
# Processing Record 47 of Set 6 | aykhal
# Processing Record 48 of Set 6 | key largo
# Processing Record 49 of Set 6 | dalvik
# Processing Record 50 of Set 6 | qaqortoq
# Processing Record 1 of Set 7 | severo-kurilsk
# Processing Record 2 of Set 7 | along
# Processing Record 3 of Set 7 | hals
# Processing Record 4 of Set 7 | katherine
# Processing Record 5 of Set 7 | riohacha
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | slave lake
# Processing Record 8 of Set 7 | ilhabela
# Processing Record 9 of Set 7 | algiers
# Processing Record 10 of Set 7 | homer
# Processing Record 11 of Set 7 | obigarm
# Processing Record 12 of Set 7 | baruun-urt
# Processing Record 13 of Set 7 | sokoni
# Processing Record 14 of Set 7 | grafton
# Processing Record 15 of Set 7 | okhotsk
# Processing Record 16 of Set 7 | san juan
# Processing Record 17 of Set 7 | bolshaya martynovka
# Processing Record 18 of Set 7 | plettenberg bay
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 7 | biak
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | bethel
# Processing Record 24 of Set 7 | parabel
# Processing Record 25 of Set 7 | nalut
# Processing Record 26 of Set 7 | narsaq
# Processing Record 27 of Set 7 | cap-aux-meules
# Processing Record 28 of Set 7 | provideniya
# Processing Record 29 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 7 | lazi
# Processing Record 31 of Set 7 | tilichiki
# Processing Record 32 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 33 of Set 7 | srandakan
# Processing Record 34 of Set 7 | ilorin
# Processing Record 35 of Set 7 | vostok
# Processing Record 36 of Set 7 | kutum
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | port moresby
# Processing Record 39 of Set 7 | rincon
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 7 | pemangkat
# Processing Record 43 of Set 7 | camacupa
# Processing Record 44 of Set 7 | panaba
# Processing Record 45 of Set 7 | novichikha
# Processing Record 46 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 47 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 7 | buraydah
# Processing Record 49 of Set 7 | ola
# Processing Record 50 of Set 7 | saint-augustin
# Processing Record 1 of Set 8 | cascais
# Processing Record 2 of Set 8 | vallenar
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | krasnoselkup
# Processing Record 5 of Set 8 | riviere-au-renard
# Processing Record 6 of Set 8 | njeru
# Processing Record 7 of Set 8 | khash
# Processing Record 8 of Set 8 | kemijarvi
# Processing Record 9 of Set 8 | porto walter
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | la ronge
# Processing Record 14 of Set 8 | vestmanna
# Processing Record 15 of Set 8 | kirkwall
# Processing Record 16 of Set 8 | eureka
# Processing Record 17 of Set 8 | mayo
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | bougouni
# Processing Record 20 of Set 8 | agadez
# Processing Record 21 of Set 8 | sao desiderio
# Processing Record 22 of Set 8 | fergus falls
# Processing Record 23 of Set 8 | miandrivazo
# Processing Record 24 of Set 8 | longyearbyen
# Processing Record 25 of Set 8 | port blair
# Processing Record 26 of Set 8 | teya
# Processing Record 27 of Set 8 | xining
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | kiri buru
# Processing Record 30 of Set 8 | oster
# Processing Record 31 of Set 8 | faanui
# Processing Record 32 of Set 8 | pisco
# Processing Record 33 of Set 8 | maniitsoq
# Processing Record 34 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | praia
# Processing Record 38 of Set 8 | mangochi
# Processing Record 39 of Set 8 | at-bashi
# Processing Record 40 of Set 8 | dunda
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | bambanglipuro
# Processing Record 43 of Set 8 | geraldton
# Processing Record 44 of Set 8 | isla vista
# Processing Record 45 of Set 8 | acapulco
# Processing Record 46 of Set 8 | sao jose da coroa grande
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | lasa
# Processing Record 49 of Set 8 | mopipi
# Processing Record 50 of Set 8 | praia da vitoria
# Processing Record 1 of Set 9 | west seneca
# Processing Record 2 of Set 9 | ambilobe
# Processing Record 3 of Set 9 | bellary
# Processing Record 4 of Set 9 | seoul
# Processing Record 5 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | villa vazquez
# City not found. Skipping...
# Processing Record 8 of Set 9 | agarak
# Processing Record 9 of Set 9 | lagos
# Processing Record 10 of Set 9 | kaili
# Processing Record 11 of Set 9 | ishigaki
# Processing Record 12 of Set 9 | salalah
# Processing Record 13 of Set 9 | khawhai
# Processing Record 14 of Set 9 | ossora
# Processing Record 15 of Set 9 | luderitz
# Processing Record 16 of Set 9 | thunder bay
# Processing Record 17 of Set 9 | sibolga
# Processing Record 18 of Set 9 | vila
# Processing Record 19 of Set 9 | shingu
# Processing Record 20 of Set 9 | weihai
# Processing Record 21 of Set 9 | port-gentil
# Processing Record 22 of Set 9 | paamiut
# Processing Record 23 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 24 of Set 9 | vilyuysk
# Processing Record 25 of Set 9 | amapa
# Processing Record 26 of Set 9 | solwezi
# Processing Record 27 of Set 9 | sirohi
# Processing Record 28 of Set 9 | padang
# Processing Record 29 of Set 9 | westport
# Processing Record 30 of Set 9 | kavaratti
# Processing Record 31 of Set 9 | nikel
# Processing Record 32 of Set 9 | ipora
# Processing Record 33 of Set 9 | bafilo
# Processing Record 34 of Set 9 | fort saint james
# Processing Record 35 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 9 | richards bay
# Processing Record 37 of Set 9 | amurzet
# Processing Record 38 of Set 9 | anori
# Processing Record 39 of Set 9 | pasco
# Processing Record 40 of Set 9 | la libertad
# Processing Record 41 of Set 9 | tab
# Processing Record 42 of Set 9 | san carlos de bariloche
# Processing Record 43 of Set 9 | kimry
# Processing Record 44 of Set 9 | benjamin hill
# Processing Record 45 of Set 9 | baykit
# Processing Record 46 of Set 9 | rio gallegos
# Processing Record 47 of Set 9 | victoria
# Processing Record 48 of Set 9 | sao joao da barra
# Processing Record 49 of Set 9 | moron
# Processing Record 50 of Set 9 | iqaluit
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | dicabisagan
# Processing Record 3 of Set 10 | alghero
# Processing Record 4 of Set 10 | arman
# Processing Record 5 of Set 10 | batabano
# Processing Record 6 of Set 10 | namwala
# Processing Record 7 of Set 10 | kogon
# Processing Record 8 of Set 10 | balikpapan
# Processing Record 9 of Set 10 | kaeo
# Processing Record 10 of Set 10 | skelleftea
# Processing Record 11 of Set 10 | mahebourg
# Processing Record 12 of Set 10 | zapolyarnyy
# Processing Record 13 of Set 10 | bahia de caraquez
# Processing Record 14 of Set 10 | olinda
# Processing Record 15 of Set 10 | erechim
# Processing Record 16 of Set 10 | kolaras
# Processing Record 17 of Set 10 | merauke
# Processing Record 18 of Set 10 | simao
# Processing Record 19 of Set 10 | kudahuvadhoo
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | okitipupa
# Processing Record 22 of Set 10 | solnechnyy
# Processing Record 23 of Set 10 | toyoshina
# Processing Record 24 of Set 10 | port hardy
# Processing Record 25 of Set 10 | tomatlan
# Processing Record 26 of Set 10 | tashtyp
# Processing Record 27 of Set 10 | marzuq
# Processing Record 28 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 29 of Set 10 | zhangye
# Processing Record 30 of Set 10 | kegums
# Processing Record 31 of Set 10 | auki
# Processing Record 32 of Set 10 | itarema
# Processing Record 33 of Set 10 | flin flon
# Processing Record 34 of Set 10 | mana
# Processing Record 35 of Set 10 | azad shahr
# Processing Record 36 of Set 10 | tasiilaq
# Processing Record 37 of Set 10 | novyy urgal
# Processing Record 38 of Set 10 | palauig
# Processing Record 39 of Set 10 | paros
# Processing Record 40 of Set 10 | dali
# Processing Record 41 of Set 10 | antofagasta
# Processing Record 42 of Set 10 | hohhot
# Processing Record 43 of Set 10 | henties bay
# Processing Record 44 of Set 10 | maracas
# Processing Record 45 of Set 10 | baft
# Processing Record 46 of Set 10 | ponerihouen
# Processing Record 47 of Set 10 | batagay
# Processing Record 48 of Set 10 | sambava
# Processing Record 49 of Set 10 | busayra
# Processing Record 50 of Set 10 | tuatapere
# Processing Record 1 of Set 11 | chuguyevka
# Processing Record 2 of Set 11 | esmeraldas
# Processing Record 3 of Set 11 | gigmoto
# Processing Record 4 of Set 11 | maragogi
# Processing Record 5 of Set 11 | tasgaon
# Processing Record 6 of Set 11 | margate
# Processing Record 7 of Set 11 | yeniseysk
# Processing Record 8 of Set 11 | soe
# Processing Record 9 of Set 11 | pitimbu
# Processing Record 10 of Set 11 | floro
# Processing Record 11 of Set 11 | agirish
# Processing Record 12 of Set 11 | kadom
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | jutai
# Processing Record 15 of Set 11 | narok
# Processing Record 16 of Set 11 | butembo
# Processing Record 17 of Set 11 | constitucion
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | yaring
# Processing Record 21 of Set 11 | nabire
# Processing Record 22 of Set 11 | ferme-neuve
# Processing Record 23 of Set 11 | broome
# Processing Record 24 of Set 11 | caucaia
# Processing Record 25 of Set 11 | taloqan
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | tongren
# Processing Record 28 of Set 11 | diffa
# Processing Record 29 of Set 11 | barra dos coqueiros
# Processing Record 30 of Set 11 | chicama
# Processing Record 31 of Set 11 | champerico
# Processing Record 32 of Set 11 | besleney
# Processing Record 33 of Set 11 | airai
# Processing Record 34 of Set 11 | sturgeon bay
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | lensk
# Processing Record 37 of Set 11 | lugovoy
# Processing Record 38 of Set 11 | dukat
# Processing Record 39 of Set 11 | mbini
# Processing Record 40 of Set 11 | zhigansk
# Processing Record 41 of Set 11 | druzhba
# Processing Record 42 of Set 11 | aksarka
# Processing Record 43 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 44 of Set 11 | malakal
# Processing Record 45 of Set 11 | mazamari
# Processing Record 46 of Set 11 | kaniama
# Processing Record 47 of Set 11 | boddam
# Processing Record 48 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 11 | bellegarde-sur-valserine
# Processing Record 50 of Set 11 | manta
# Processing Record 1 of Set 12 | kota kinabalu
# Processing Record 2 of Set 12 | myre
# Processing Record 3 of Set 12 | inongo
# Processing Record 4 of Set 12 | sao joao dos patos
# Processing Record 5 of Set 12 | kondoros
# Processing Record 6 of Set 12 | glencoe
# Processing Record 7 of Set 12 | talnakh
# Processing Record 8 of Set 12 | camenca
# Processing Record 9 of Set 12 | qom
# Processing Record 10 of Set 12 | los llanos de aridane
# Processing Record 11 of Set 12 | camacha
# Processing Record 12 of Set 12 | sangar
# Processing Record 13 of Set 12 | murakami
# Processing Record 14 of Set 12 | antalaha
# Processing Record 15 of Set 12 | gouyave
# Processing Record 16 of Set 12 | faya
# Processing Record 17 of Set 12 | pavlogradka
# Processing Record 18 of Set 12 | loding
# Processing Record 19 of Set 12 | roswell
# Processing Record 20 of Set 12 | wanning
# Processing Record 21 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 22 of Set 12 | dondo
# Processing Record 23 of Set 12 | kautokeino
# Processing Record 24 of Set 12 | sturgis
# Processing Record 25 of Set 12 | shenkursk
# Processing Record 26 of Set 12 | pali
# Processing Record 27 of Set 12 | armidale
# Processing Record 28 of Set 12 | kraslava
# Processing Record 29 of Set 12 | launceston
# Processing Record 30 of Set 12 | callaway
# Processing Record 31 of Set 12 | mandalgovi
# Processing Record 32 of Set 12 | trairi
# Processing Record 33 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 12 | ajaccio
# Processing Record 35 of Set 12 | luganville
# Processing Record 36 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 12 | pochutla
# Processing Record 38 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 12 | bo
# City not found. Skipping...
# Processing Record 40 of Set 12 | partenit
# Processing Record 41 of Set 12 | tahta
# Processing Record 42 of Set 12 | troitskoye
# Processing Record 43 of Set 12 | fortuna
# Processing Record 44 of Set 12 | george
# Processing Record 45 of Set 12 | torva
# Processing Record 46 of Set 12 | cottage grove
# Processing Record 47 of Set 12 | kayankulam
# Processing Record 48 of Set 12 | sunbury
# Processing Record 49 of Set 12 | omboue
# Processing Record 50 of Set 12 | mbanza-ngungu
# Processing Record 1 of Set 13 | ovalle
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | lumphat
# Processing Record 4 of Set 13 | shangrao
# Processing Record 5 of Set 13 | marsh harbour
# Processing Record 6 of Set 13 | dedza
# Processing Record 7 of Set 13 | nueva loja
# Processing Record 8 of Set 13 | jieznas
# Processing Record 9 of Set 13 | moore
# Processing Record 10 of Set 13 | ahuimanu
# Processing Record 11 of Set 13 | killarney
# Processing Record 12 of Set 13 | mantua
# Processing Record 13 of Set 13 | the pas
# Processing Record 14 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 13 | presidente medici
# Processing Record 16 of Set 13 | itaituba
# Processing Record 17 of Set 13 | urengoy
# Processing Record 18 of Set 13 | vanimo
# Processing Record 19 of Set 13 | januaria
# Processing Record 20 of Set 13 | pedasi
# Processing Record 21 of Set 13 | polovinnoye
# Processing Record 22 of Set 13 | altamira
# Processing Record 23 of Set 13 | uruzgan
# Processing Record 24 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 13 | vesoul
# Processing Record 26 of Set 13 | kayes
# Processing Record 27 of Set 13 | nuuk
# Processing Record 28 of Set 13 | agadir
# Processing Record 29 of Set 13 | bahir dar
# Processing Record 30 of Set 13 | hami
# Processing Record 31 of Set 13 | khuzdar
# Processing Record 32 of Set 13 | san quintin
# Processing Record 33 of Set 13 | beidao
# Processing Record 34 of Set 13 | preobrazheniye
# Processing Record 35 of Set 13 | bereda
# Processing Record 36 of Set 13 | riyadh
# Processing Record 37 of Set 13 | beyneu
# Processing Record 38 of Set 13 | streetsboro
# Processing Record 39 of Set 13 | neuquen
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | ballina
# Processing Record 42 of Set 13 | tolaga bay
# Processing Record 43 of Set 13 | keetmanshoop
# Processing Record 44 of Set 13 | manacapuru
# Processing Record 45 of Set 13 | vaasa
# Processing Record 46 of Set 13 | polunochnoye
# Processing Record 47 of Set 13 | killybegs
# Processing Record 48 of Set 13 | svetlaya
# Processing Record 49 of Set 13 | tahoua
# Processing Record 50 of Set 13 | ormara
# Processing Record 1 of Set 14 | tripoli
# Processing Record 2 of Set 14 | belmonte
# Processing Record 3 of Set 14 | lentekhi
# Processing Record 4 of Set 14 | luanda
# Processing Record 5 of Set 14 | almeria
# Processing Record 6 of Set 14 | dawei
# Processing Record 7 of Set 14 | bowen
# Processing Record 8 of Set 14 | ust-tsilma
# Processing Record 9 of Set 14 | xiaoshi
# Processing Record 10 of Set 14 | izumo
# Processing Record 11 of Set 14 | saint-denis
# Processing Record 12 of Set 14 | north platte
# Processing Record 13 of Set 14 | chegdomyn
# Processing Record 14 of Set 14 | chapais
# Processing Record 15 of Set 14 | sinop
# Processing Record 16 of Set 14 | beruwala
# Processing Record 17 of Set 14 | fairlie
# Processing Record 18 of Set 14 | shar
# Processing Record 19 of Set 14 | kawalu
# Processing Record 20 of Set 14 | constantine
# Processing Record 21 of Set 14 | lembeni
# Processing Record 22 of Set 14 | skibbereen
# Processing Record 23 of Set 14 | korla
# Processing Record 24 of Set 14 | prince rupert
# Processing Record 25 of Set 14 | huntingdon
# Processing Record 26 of Set 14 | plainview
# Processing Record 27 of Set 14 | labuhan
# Processing Record 28 of Set 14 | kampot
# Processing Record 29 of Set 14 | gorontalo
# Processing Record 30 of Set 14 | opuwo
# Processing Record 31 of Set 14 | nome
# Processing Record 32 of Set 14 | flinders
# Processing Record 33 of Set 14 | hegra
# Processing Record 34 of Set 14 | balkhash
# Processing Record 35 of Set 14 | cravo norte
# Processing Record 36 of Set 14 | denpasar
# Processing Record 37 of Set 14 | bukachacha
# Processing Record 38 of Set 14 | wewak
# Processing Record 39 of Set 14 | campoverde
# Processing Record 40 of Set 14 | gat
# Processing Record 41 of Set 14 | rundu
# Processing Record 42 of Set 14 | yarada
# Processing Record 43 of Set 14 | angoche
# Processing Record 44 of Set 14 | galiakot
# Processing Record 45 of Set 14 | tromso
# Processing Record 46 of Set 14 | mount isa
# Processing Record 47 of Set 14 | ottawa
# Processing Record 48 of Set 14 | srednekolymsk
# Processing Record 49 of Set 14 | djougou
# Processing Record 50 of Set 14 | pechenga
# Processing Record 1 of Set 15 | poya
# Processing Record 2 of Set 15 | isabela
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | bud
# Processing Record 5 of Set 15 | turukhansk
# Processing Record 6 of Set 15 | liverpool
# Processing Record 7 of Set 15 | kysyl-syr
# Processing Record 8 of Set 15 | margherita di savoia
# Processing Record 9 of Set 15 | puerto ayacucho
# Processing Record 10 of Set 15 | quang ngai
# Processing Record 11 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 15 | loralai
# Processing Record 13 of Set 15 | gunjur
# Processing Record 14 of Set 15 | lichinga
# Processing Record 15 of Set 15 | astoria
# Processing Record 16 of Set 15 | waddan
# Processing Record 17 of Set 15 | bac lieu
# Processing Record 18 of Set 15 | cookeville
# Processing Record 19 of Set 15 | tessalit
# Processing Record 20 of Set 15 | augusta
# Processing Record 21 of Set 15 | sept-iles
# Processing Record 22 of Set 15 | springdale
# Processing Record 23 of Set 15 | port pirie
# Processing Record 24 of Set 15 | osvaldo cruz
# Processing Record 25 of Set 15 | gelendzhik
# Processing Record 26 of Set 15 | porto velho
# Processing Record 27 of Set 15 | dori
# Processing Record 28 of Set 15 | caravelas
# Processing Record 29 of Set 15 | gambela
# Processing Record 30 of Set 15 | sindor
# Processing Record 31 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 15 | mudkhed
# Processing Record 33 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 15 | healdsburg
# Processing Record 35 of Set 15 | taltal
# Processing Record 36 of Set 15 | tabuk
# Processing Record 37 of Set 15 | rawson
# Processing Record 38 of Set 15 | kapuskasing
# Processing Record 39 of Set 15 | awbari
# Processing Record 40 of Set 15 | vitina
# Processing Record 41 of Set 15 | apostolove
# Processing Record 42 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 43 of Set 15 | saint-francois
# Processing Record 44 of Set 15 | viedma
# Processing Record 45 of Set 15 | necochea
# Processing Record 46 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 47 of Set 15 | newark
# Processing Record 48 of Set 15 | ust-nera
# Processing Record 49 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 15 | port hawkesbury
# Processing Record 1 of Set 16 | nowogard
# Processing Record 2 of Set 16 | puerto carreno
# Processing Record 3 of Set 16 | gamba
# Processing Record 4 of Set 16 | tortoli
# Processing Record 5 of Set 16 | palana
# Processing Record 6 of Set 16 | kisesa
# Processing Record 7 of Set 16 | kaseda
# Processing Record 8 of Set 16 | kamenz
# Processing Record 9 of Set 16 | camalu
# Processing Record 10 of Set 16 | soyo
# Processing Record 11 of Set 16 | sigerfjord
# City not found. Skipping...
# Processing Record 12 of Set 16 | bondo
# Processing Record 13 of Set 16 | berlevag
# Processing Record 14 of Set 16 | sembe
# Processing Record 15 of Set 16 | san luis
# Processing Record 16 of Set 16 | khartoum
# Processing Record 17 of Set 16 | taber
# Processing Record 18 of Set 16 | lesnoy
# Processing Record 19 of Set 16 | warrington
# Processing Record 20 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 16 | sokur
# Processing Record 22 of Set 16 | rapina
# Processing Record 23 of Set 16 | dandong
# Processing Record 24 of Set 16 | rocha
# Processing Record 25 of Set 16 | verkhnevilyuysk
# Processing Record 26 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 16 | saint-pierre
# Processing Record 28 of Set 16 | orange walk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 721

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     78.39        76          88
# 1          Sakata      JP  38.9167  139.8550     33.98        80          75
# 2          Murgab      TM  37.4966   61.9714     44.47        81          90
# 3          Atuona      PF  -9.8000 -139.0333     79.18        77          16
# 4        Klaksvik      FO  62.2266   -6.5890     40.12        69         100
# 5         Mataura      NZ -46.1927  168.8643     61.48        50          64
# 6      Brigantine      US  39.4101  -74.3646     47.01        52           1
# 7         Rikitea      PF -23.1203 -134.9692     77.31        77          87
# 8     Tuktoyaktuk      CA  69.4541 -133.0374     -5.80        77          90
# 9      Bredasdorp      ZA -34.5322   20.0403     61.29        88         100
#
#    Wind Speed          Current Description
# 0       11.45              overcast clouds
# 1       32.21                   light rain
# 2        9.22  light intensity shower rain
# 3       19.22                   few clouds
# 4       17.81              overcast clouds
# 5        2.13                broken clouds
# 6        5.75                    clear sky
# 7        9.42                   light rain
# 8       18.41                   light snow
# 9        3.00              overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
